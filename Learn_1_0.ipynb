# %% [markdown]
# <a href="https://colab.research.google.com/github/Abidah15/My_Notes-GColab/blob/main/Learn_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science**

# %% [markdown]
# **Big Data**

# %% [markdown]
# *Python*

# %% [markdown]
# 1.   Python
# 2.   Javascript

# %% [markdown]
# [Click here to follow my LinkedIn](https://www.linkedin.com/in/nurul-abidah-shukor-b105a0178)

# %% [markdown]
# ![WhatsApp Image 2024-07-06 at 12.26.39 (2).jpeg](data:image/jpeg;base64,...)
